# %% [markdown]
# # EDA -Exploratory Data Analysis

# %% [markdown]
# # Objectives
#
# 1. Data Collection
#
# 2. Data Understanding
#
# 3. Data Cleaning
#
# 4. Univariant Analysis
#
# 5. Date & Time Insights
#
# 6. Basic Visualization
#
# 7. Summary
#
# 8. Recommendation

# %%
# Import libraries
import numpy as pd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Step 1 - Data collection

# %%
df = pd.read_csv('amazon_prime_titles.csv')
df
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %% [markdown]
# # Step 2 - Data understanding

# %%
#to see first 5 rows
df.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %%
#to see last 5 rows
df.tail()
# Out:
#      show_id     type                    title         director  \
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast country date_added  \
# 9663                           Leo Gorcey, Bobby Jordan     NaN        NaN
# 9664  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...     NaN        NaN
# 9665  Ray Stevenson, Julian Wadham, Richard Brake, M...     NaN        NaN
# 9666  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...     NaN        NaN
# 9667  Michael Caine, Emily Mortimer, Joseph Gilgun, ...     NaN        NaN
#
#       release_year rating   duration                listed_in  \
# 9663          1940     7+     60 min                   Comedy
# ...

# %%
#check shape of data
df.shape
# Out:
# (9668, 12)

# %%
#to display the columns
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#to find data type
print(df.dtypes)
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# basic statistics for numerical value
df.describe()
# Out:
#        release_year
# count   9668.000000
# mean    2008.341849
# std       18.922482
# min     1920.000000
# 25%     2007.000000
# 50%     2016.000000
# 75%     2019.000000
# max     2021.000000

# %%
#general information of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7585 non-null   object
#  4   cast          8435 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    object
#  7   release_year  9668 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9668 non-null   object
#  10  listed_in     9668 non-null   object
#  11  description   9668 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 906.5+ KB

# %% [markdown]
# - It indicates that there are total of 9668 movie details among which 2083 movies Director is missing, 1233 movies Cast details are also missing, 8996 movies Country details are also missing, 9513 movies date_added details were also missing and 337 movies rating details are also missing.

# %% [markdown]
# # Step 3-Data cleaning

# %%
#check null values
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2083
# cast            1233
# country         8996
# date_added      9513
# release_year       0
# rating           337
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
# heatmap before handling null
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#to check duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Creating the Data Dictionary with first column being datatype:

Data_dict = pd.DataFrame(df.dtypes)
Data_dict
# Out:
#                    0
# show_id       object
# type          object
# title         object
# director      object
# cast          object
# country       object
# date_added    object
# release_year   int64
# rating        object
# duration      object
# listed_in     object
# description   object

# %%
# identifying the missing values from the dataset:

Data_dict['MissingVal'] = df.isnull().sum()
Data_dict
# Out:
#                    0  MissingVal
# show_id       object           0
# type          object           0
# title         object           0
# director      object        2083
# cast          object        1233
# country       object        8996
# date_added    object        9513
# release_year   int64           0
# rating        object         337
# duration      object           0
# listed_in     object           0
# description   object           0

# %%
# Dropping the unneccesary columns:

df.drop(['show_id'], axis = 1, inplace = True)
df.drop(['date_added'], axis = 1, inplace = True)
df.drop(['description'], axis = 1, inplace = True)

# %%
# Handling missing value:

df['director'].fillna('Not mention', inplace=True)
df['cast'].fillna('Not Mention', inplace=True)
df['country'].fillna('Not Mention', inplace=True)
df['rating']=df['rating'].fillna(df['rating'].mode()[0])

# %%
# Basic Statistics view of numerical value:

df.describe()
# Out:
#        release_year
# count   9668.000000
# mean    2008.341849
# std       18.922482
# min     1920.000000
# 25%     2007.000000
# 50%     2016.000000
# 75%     2019.000000
# max     2021.000000

# %%
# To see the categorical statistic:

df.describe(include='O')
# Out:
#          type                title     director         cast      country  \
# count    9668                 9668         9668         9668         9668
# unique      2                 9668         5774         7928           87
# top     Movie  The Grand Seduction  Not mention  Not Mention  Not Mention
# freq     7814                    1         2083         1233         8996
#
#        rating  duration listed_in
# count    9668      9668      9668
# unique     24       219       518
# top       13+  1 Season     Drama
# freq     2454      1342       986

# %%
# Checking missing values after handling:

df.isnull().sum()
# Out:
# type            0
# title           0
# director        0
# cast            0
# country         0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
# Heatmap after handling:

sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# - A heatmap is a visual representation of data where different values are shown using colors. It helps in identifying patterns, correlations, and missing values in a dataset.

# %% [markdown]
# # Step 4 - Univariant Analysis

# %% [markdown]
# ## 4.1 Count of shows by type

# %%
# Count of shows by type:

type_counts = df['type'].value_counts()
print("Count of shows by type:")
print(type_counts)
# Out:
# Count of shows by type:
# type
# Movie      7814
# TV Show    1854
# Name: count, dtype: int64

# %%
# in pie chart for count of shows by type (movie vs tv show):

plt.figure(figsize=(8, 6))
type_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90,colors = ["#FF6347", "#708090"])
plt.title('Distribution of Content Types')
plt.ylabel('')
plt.show()

# %% [markdown]
# ## 4.2 Top genres or categories

# %%
# Top genres:

top_genres = df['listed_in'].value_counts().head(10)
top_genres
# Out:
# listed_in
# Drama                            986
# Comedy                           536
# Drama, Suspense                  399
# Comedy, Drama                    377
# Animation, Kids                  356
# Documentary                      350
# Kids                             334
# Action, Drama                    297
# Documentary, Special Interest    296
# TV Shows                         263
# Name: count, dtype: int64

# %%
# in bar chart for top genres or categories:

plt.figure(figsize=(12, 6))
sns.barplot(x=top_genres.values, y=top_genres.index, palette='muted')
plt.title('Top 10 Genres')
plt.xlabel('Number of Movies')
plt.ylabel('Genre')
plt.show()

# %% [markdown]
# ## 4.3 Frequency of ratings

# %%
# Counts of Rating: 

rating_counts = df['rating'].value_counts()
print("\nCounts of rating:")
print(rating_counts)
# Out:
# Counts of rating:
# rating
# 13+         2454
# 16+         1547
# ALL         1268
# 18+         1243
# R           1010
# PG-13        393
# 7+           385
# PG           253
# NR           223
# TV-14        208
# TV-PG        169
# TV-NR        105
# G             93
# TV-G          81
# TV-MA         77
# TV-Y          74
# TV-Y7         39
# UNRATED       33
# NC-17          3
# AGES_18_       3
# NOT_RATE       3
# AGES_16_       2
# 16             1
# ALL_AGES       1
# Name: count, dtype: int64

# %%
# in bar chart for Frequency Ratings:

rating_counts.plot(kind='bar',color="#708090")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.title("Frequency Ratings")
plt.show()

# %% [markdown]
# # Step 5: Date & Time Insights

# %% [markdown]
# ## 5.1 Release year  based distribution

# %%
# release year based distribution:

if 'release_year' in df.columns:
    release_counts = df['release_year'].value_counts().sort_index()
    print("\nContent release by year:")
    print(release_counts.tail(10))
# Out:
# Content release by year:
# release_year
# 2012     252
# 2013     289
# 2014     391
# 2015     378
# 2016     521
# 2017     562
# 2018     623
# 2019     929
# 2020     962
# 2021    1442
# Name: count, dtype: int64

# %%
# in line chart for release year based distribution:

release_counts.plot(kind='line')

# line chart

plt.plot(release_counts, marker = 'o', linestyle = '-', color='#708090',label = 'release year')
plt.xlabel('Year')
plt.ylabel('Number of Releases')
plt.title('Release Year Based Distribution')
plt.grid()
plt.show()

# %%
# in bar chart trends overtime in content release:

recent_years = release_counts.tail(10)
recent_years.plot(kind='bar',color="#708090")
plt.xlabel('Year')
plt.ylabel('Number of Releases')
plt.show()

# %% [markdown]
# # Step 6: Basic Visualizations

# %% [markdown]
# ## 6.1 Bar charts

# %%
# in bar chart for top genres:

plt.figure(figsize=(12, 6))
sns.barplot(x=top_genres.values, y=top_genres.index, palette='muted')
plt.title('Top 10 Genres')
plt.xlabel('Number of Movies')
plt.ylabel('Genre')
plt.show()

# %%
# in bar chart for Frequency Ratings:

rating_counts.plot(kind='bar',color="#708090")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.title("Frequency Ratings")
plt.show()

# %% [markdown]
# ## 6.2 Line Chart

# %%
# in line chart for release year-wise content count:

release_counts.plot(kind='line')

# line chart

plt.plot(release_counts, marker = 'o', linestyle = '-', color='#708090',label = 'release year')
plt.xlabel('Year')
plt.ylabel('Number of Releases')
plt.title('Release Year Based Distribution')
plt.grid()
plt.show()

# %% [markdown]
# ## 6.3 Pie chart

# %%
# in Pie chart for content type distribution:

plt.figure(figsize=(8, 6))
type_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90,colors = ["#FF6347", "#708090"])
plt.title('Distribution of Content Types')
plt.ylabel('')
plt.show()

# %% [markdown]
# ## 7)Summary

# %% [markdown]
# 1. Amazon Prime has more Movies (81%) compared to TV Shows (19%).
# 2. Drama & Comedy are the most common genres.
# 3. Most shows are rated 13+ and 16+, focusing on teens/family-friendly content.
# 4. Huge rise in content production after 2010, peaking in 2021.

# %% [markdown]
# ## 8) Recommendations

# %% [markdown]
# - Strengthen top-performing genres with original productions, while testing spin-offs or cross-genre hybrids to diversify the slate.
# - Expand multi-language dubbing/subtitles for top non-English languages to improve reach and completion rates.
# - Curate year-themed collections (e.g., 'Classics from 1990s', 'Hits of 2010s') to resurface back-catalog titles and drive engagement.
# - Use content ratings insights to optimize parental controls and personalized profiles (e.g., more PG/PG-13 family rows if those are dominant).
# - If Movies dominate, serialize popular movie IP into limited series; if TV Shows dominate, produce event movies to create weekend watch-time spikes.

# %%
df.to_csv('processed_data.csv', index=False)
